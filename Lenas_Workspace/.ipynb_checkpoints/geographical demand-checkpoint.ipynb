# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
display(HTML(""))
import scienceplots
plt.style.use(['science', 'no-latex'])
import folium
from folium import plugins
from folium.plugins import HeatMap

# %%
# import
la = pd.read_csv("prepared_data.csv", parse_dates=["start_time","end_time"],low_memory=False)

# %%
la.head(3)
# Out:
#    Unnamed: 0          start_time            end_time  start_station_id  \
# 0           0 2019-01-01 00:07:00 2019-01-01 00:14:00              3046
# 1           1 2019-01-01 00:08:00 2019-01-01 00:14:00              3046
# 2           2 2019-01-01 00:18:00 2019-01-01 00:50:00              3030
#
#    end_station_id bike_id user_type start_station_name end_station_name  \
# 0            3051   06468   Walk-up         2nd & Hill   7th & Broadway
# 1            3051   12311   Walk-up         2nd & Hill   7th & Broadway
# 2            3075   05992   Walk-up         Main & 1st   Broadway & 9th
#
#    duration        date  month  weekday  day  hour
# 0       7.0  2019-01-01      1        1    1     0
# 1       6.0  2019-01-01      1        1    1     0
# 2      32.0  2019-01-01      1        1    1     0

# %%
# counting which station is used how often
start_count = la['start_station_name'].value_counts()
end_count = la['end_station_name'].value_counts()

# %%
# new dataframe 
station_df = start_count.to_frame().rename(columns = {'start_station_name': 'start_count'})
station_df['end_count'] = end_count
station_df['sum'] = station_df['start_count'] + station_df['end_count']
station_df['station_name'] = station_df.index
station_df = station_df.sort_values(by='sum', ascending=False)
station_df.reset_index(drop=True, inplace=True) 
station_df.head(3)
# Out:
#    start_count  end_count    sum               station_name
# 0        13890      14630  28520               7th & Flower
# 1        13005      11377  24382                 Main & 1st
# 2        10783      11996  22779  Union Station West Portal

# %%
# plot of 50 most used stations
fig, ax = plt.subplots(figsize=[15,5])
plt.setp(ax.xaxis.get_majorticklabels(),rotation=90,fontsize=10)
ax.bar(station_df['station_name'].iloc[:50], station_df['sum'].iloc[:50])
plt.title('50 most used stations')
# Out:
# Text(0.5, 1.0, '50 most used stations')

# %%
# plot of 50 least used stations
fig, ax = plt.subplots(figsize=[15,5])
plt.setp(ax.xaxis.get_majorticklabels(),rotation=90,fontsize=10)
ax.bar(station_df['station_name'].iloc[-50:], station_df['sum'].iloc[-50:])
plt.title('50 least used stations')
plt.show()

# %%
# new dataframe for most used routes
la["route"] = (la["start_station_name"] +" to "+ la["end_station_name"])
route = la['route'].value_counts()
route_df = route.to_frame().rename(columns={'route': 'count'})
route_df['route'] = route_df.index
route_df.head(3)
# Out:
#                                                     count  \
# Main & 1st to Union Station West Portal              5135
# Union Station West Portal to Main & 1st              4395
# Ocean Front Walk & Navy to Ocean Front Walk & Navy   4080
#
#                                                                                                 route
# Main & 1st to Union Station West Portal                       Main & 1st to Union Station West Portal
# Union Station West Portal to Main & 1st                       Union Station West Portal to Main & 1st
# Ocean Front Walk & Navy to Ocean Front Walk & Navy  Ocean Front Walk & Navy to Ocean Front Walk & ...

# %%
# plot of 20 most traveled routes
fig, ax = plt.subplots(figsize=[15,5])
plt.setp(ax.xaxis.get_majorticklabels(),rotation=90,fontsize=10)
ax.bar(route_df['route'].iloc[:20], route_df['count'].iloc[:20])
plt.show()

# %%
# new data set with station information (locations)
# https://gbfs.bcycle.com/bcycle_lametro/station_information.json
coordinates = pd.read_csv("station_information.csv")
# drop unnecessary columns
coordinates = coordinates.drop(columns=['ttl', 'data__stations__rental_uris__ios','data__stations__rental_uris__android','version','last_updated'])
coordinates.head(3)
# Out:
#    data__stations__lon  data__stations__lat  \
# 0           -118.25854             34.04850
# 1           -118.25667             34.04554
# 2           -118.25459             34.05048
#
#   data__stations___bcycle_station_type data__stations__region_id  \
# 0                    Kiosk and Station   bcycle_lametro_region_1
# 1                    Kiosk and Station   bcycle_lametro_region_1
# 2                    Kiosk and Station   bcycle_lametro_region_1
#
#   data__stations__address data__stations__name data__stations__station_id
# 0        Reinstalled 6/15         7th & Flower        bcycle_lametro_3005
# 1      729 S Olive Street          Olive & 8th        bcycle_lametro_3006
# 2        557 S 5th Street          5th & Grand        bcycle_lametro_3007

# %%
# adding coordinates to stations
coordinates["ziped_coords"] = list(zip(coordinates["data__stations__lat"],coordinates["data__stations__lon"]))
station_df = station_df.merge(coordinates["ziped_coords"].to_frame(),how = "left",left_on=station_df["station_name"],right_on=coordinates["data__stations__name"])
station_df = station_df.drop(columns=["key_0"])

# dropping stations without location data
station_df = station_df.dropna(axis=0)
station_df.head(3)
# Out:
#    start_count  end_count    sum               station_name  \
# 0        13890      14630  28520               7th & Flower
# 1        13005      11377  24382                 Main & 1st
# 2        10783      11996  22779  Union Station West Portal
#
#              ziped_coords
# 0   (34.0485, -118.25854)
# 1  (34.05194, -118.24353)
# 2  (34.05661, -118.23721)

# %%
# stations; size --> logarithmic number of started tours
log_map = folium.Map(location=(34.052235, -118.243683),tiles='OpenStreetMap',zoom_start=11, control_scale=True, max_zoom=20)

# drawing maps and dots
#for index, row in station_df.iterrows():
 #   folium.CircleMarker(radius=np.power(np.log(row["activities"])/4,1.5, location=row["ziped_coords"], popup=row["station_name"], color="red", fill_color="red",weight=2).add_to(log_map)

log_map
# adding the most used stations in green
for index, row in station_df.iloc[:50].iterrows():
    folium.CircleMarker(radius=5, location=row["ziped_coords"], popup=row["station_name"], color="green", fill_color="green",weight=2).add_to(log_map)
    
#add the least used stations in red
for index, row in station_df.iloc[-50:].iterrows():
    folium.CircleMarker(radius=5, location=row["ziped_coords"], popup=row["station_name"], color="red", fill_color="red",weight=2).add_to(log_map)
    
log_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62c490e972f1209b11f2eae8ba543841 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62c490e972f1209b11f2eae8ba543841&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62c490e972f1209b11f2eae8ba543841 = L.map(
#                 &quot;map_62c490e972f1209b11f2eae8ba543841&quot;,
#                 {
#                     center: [34.052235, -118.243683],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_62c490e972f1209b11f2eae8ba543841);
#
#
#
#
#
#             var tile_layer_3b441b1d593c4d7dd9b0a7607e2a22c1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_62c490e972f1209b11f2eae8ba543841);
#
#
#             var circle_marker_26d100c9e0a5d7f379122a66bdbce4f2 = L.circleMarker(
#                 [34.0485, -118.25854],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_62c490e972f1209b11f2eae8ba543841);
#
#
#         var popup_0f140a4cec99e1b1cd2570c71b939606 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8320ce4e12783715456f24190f5dedcf = $(`&lt;div id=&quot;html_8320ce4e12783715456f24190f5dedcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;7th &amp; Flower&lt;/div&gt;`)[0];
#                 popup_0f140a4cec99e1b1cd2570c71b939606.setContent(html_8320ce4e12783715456f24190f5dedcf);
#
#
#
#         circle_marker_26d100c9e0a5d7f379122a66bdbce4f2.bindPopup(popup_0f140a4cec99e1b1cd2570c71b939606)
#         ;
#
#
#
#
#             var circle_marker_2c180c110cbfe3d5f9130130247eda4f = L.circleMarker(
#                 [34.05194, -118.24353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_62c490e972f1209b11f2eae8ba543841);
#
#
#         var popup_72a32faa2a9619613e4e41dad77647f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c05b2e8ff2ddad37afac2f860dee18df = $(`&lt;div id=&quot;html_c05b2e8ff2ddad37afac2f860dee18df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Main &amp; 1st&lt;/div&gt;`)[0];
#                 popup_72a32faa2a9619613e4e41dad77647f9.setContent(html_c05b2e8ff2ddad37afac2f860dee18df);
#
#
#
#         circle_marker_2c180c110cbfe3d5f9130130247eda4f.bindPopup(popup_72a32faa2a9619613e4e41dad77647f9)
#         ;
#
#
#
#
#             var circle_marker_720ebc3b9a37dd8418eada316627819a = L.circleMarker(
#                 [34.05661, -118.23721],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_62c490e972f1209b11f2eae8ba543841);
#
#
#         var popup_926d70b5a1ae73fe949b021400ff16d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41678bf71eeb56eecd1b4021aafa25af = $(`&lt;div id=&quot;html_41678bf71eeb56eecd1b4021aafa25af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Union Station West Portal&lt;/div&gt;`)[0];
#                 popup_926d70b5a1ae73fe949b021400ff16d7.setContent(html_41678bf71eeb56eecd1b4021aafa25af);
#
#
#
#         circle_marker_720ebc3b9a37dd8418eada316627819a.bindPopup(popup_926d70b5a1ae73fe949b021400ff16d7)
#         ;
#
#
#
#
#             var circle_marker_6bc39f6013c268f3e6c8627635478813 = L.circleMarker(
#                 [34.0447, -118.25244],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot

# %%
user_type = la['user_type'].value_counts()

# %%
user = user_type.to_frame()
user
# Out:
#               user_type
# Monthly Pass     169677
# Walk-up           77857
# Annual Pass       21078
# One Day Pass      14128
# Flex Pass           313
# Testing              82

# %%
# stations; size --> logarithmic number of started tours
log_map_2 = folium.Map(location=(34.052235, -118.243683),tiles='OpenStreetMap',zoom_start=11, control_scale=True, max_zoom=20)

# drawing maps and dots
for index, row in station_df.iterrows():
    folium.CircleMarker(radius=np.power(np.log(row["sum"])/4,1.5), location=row["ziped_coords"], popup=row["station_name"], color="red", fill_color="red",weight=2).add_to(log_map_2)

log_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c436871e22aa0e770c222fe2e48e2602 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c436871e22aa0e770c222fe2e48e2602&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c436871e22aa0e770c222fe2e48e2602 = L.map(
#                 &quot;map_c436871e22aa0e770c222fe2e48e2602&quot;,
#                 {
#                     center: [34.052235, -118.243683],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c436871e22aa0e770c222fe2e48e2602);
#
#
#
#
#
#             var tile_layer_469cb492c3ff637075024ddcb5bcced1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c436871e22aa0e770c222fe2e48e2602);
#
#
#             var circle_marker_8749be41d25c4771f5f9392df56f739f = L.circleMarker(
#                 [34.0485, -118.25854],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.107021461548505, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c436871e22aa0e770c222fe2e48e2602);
#
#
#         var popup_d7e4438ba8e04b245d8b452c792dc32c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20192f3d38edcb90e1633b043557ef6e = $(`&lt;div id=&quot;html_20192f3d38edcb90e1633b043557ef6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;7th &amp; Flower&lt;/div&gt;`)[0];
#                 popup_d7e4438ba8e04b245d8b452c792dc32c.setContent(html_20192f3d38edcb90e1633b043557ef6e);
#
#
#
#         circle_marker_8749be41d25c4771f5f9392df56f739f.bindPopup(popup_d7e4438ba8e04b245d8b452c792dc32c)
#         ;
#
#
#
#
#             var circle_marker_f91caca7fac7c9d2c07174352947dd5d = L.circleMarker(
#                 [34.05194, -118.24353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.013241478354614, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c436871e22aa0e770c222fe2e48e2602);
#
#
#         var popup_0e48869552007d21fa9e3951fbf462d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9145374005621ae7662e01a2a5cb39a = $(`&lt;div id=&quot;html_f9145374005621ae7662e01a2a5cb39a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Main &amp; 1st&lt;/div&gt;`)[0];
#                 popup_0e48869552007d21fa9e3951fbf462d1.setContent(html_f9145374005621ae7662e01a2a5cb39a);
#
#
#
#         circle_marker_f91caca7fac7c9d2c07174352947dd5d.bindPopup(popup_0e48869552007d21fa9e3951fbf462d1)
#         ;
#
#
#
#
#             var circle_marker_41711200f5b5ef4552af370cb3109a94 = L.circleMarker(
#                 [34.05661, -118.23721],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.972782787024921, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c436871e22aa0e770c222fe2e48e2602);
#
#
#         var popup_d819f71cb0987df0bb103f9aee565ca4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ccbde414878293da80e1bd447ee11f4a = $(`&lt;div id=&quot;html_ccbde414878293da80e1bd447ee11f4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Union Station West Portal&lt;/div&gt;`)[0];
#                 popup_d819f71cb0987df0bb103f9aee565ca4.setContent(html_ccbde414878293da80e1bd447ee11f4a);
#
#
#
#         circle_marker_41711200f5b5ef4552af370cb3109a94.bindPopup(popup_d819f71cb0987df0bb103f9aee565ca4)
#         ;
#
#
#
#
#             var circle_marker_be14a81d7c549c3226a5bd374ef768de = L.circleMarker(
#                 [34.0447, -118.25244],
#                 {&quot;bubblingMouseEvents&q

# %%
# adding start station coordinates to dataframe
df_1 = la.merge(station_df[['station_name','ziped_coords']], how = 'left', left_on = ['start_station_name'], right_on = ['station_name'])
df_1.rename(columns = {'ziped_coords':'start_coords'}, inplace = True)
df_1.head(3)
# Out:
#    Unnamed: 0          start_time            end_time  start_station_id  \
# 0           0 2019-01-01 00:07:00 2019-01-01 00:14:00              3046
# 1           1 2019-01-01 00:08:00 2019-01-01 00:14:00              3046
# 2           2 2019-01-01 00:18:00 2019-01-01 00:50:00              3030
#
#    end_station_id bike_id user_type start_station_name end_station_name  \
# 0            3051   06468   Walk-up         2nd & Hill   7th & Broadway
# 1            3051   12311   Walk-up         2nd & Hill   7th & Broadway
# 2            3075   05992   Walk-up         Main & 1st   Broadway & 9th
#
#    duration        date  month  weekday  day  hour  \
# 0       7.0  2019-01-01      1        1    1     0
# 1       6.0  2019-01-01      1        1    1     0
# 2      32.0  2019-01-01      1        1    1     0
#
#                           route station_name            start_coords
# 0  2nd & Hill to 7th & Broadway   2nd & Hill  (34.05287, -118.24749)
# 1  2nd & Hill to 7th & Broadway   2nd & Hill  (34.05287, -118.24749)
# 2  Main & 1st to Broadway & 9th   Main & 1st  (34.05194, -118.24353)

# %%
# adding end station coordinates to dataframe
df_2 = df_1.merge(station_df[['station_name','ziped_coords']], how = 'left', left_on = ['end_station_name'], right_on = ['station_name'])
df_2.rename(columns = {'ziped_coords':'end_coords'}, inplace = True)
df_2.head(3)
# Out:
#    Unnamed: 0          start_time            end_time  start_station_id  \
# 0           0 2019-01-01 00:07:00 2019-01-01 00:14:00              3046
# 1           1 2019-01-01 00:08:00 2019-01-01 00:14:00              3046
# 2           2 2019-01-01 00:18:00 2019-01-01 00:50:00              3030
#
#    end_station_id bike_id user_type start_station_name end_station_name  \
# 0            3051   06468   Walk-up         2nd & Hill   7th & Broadway
# 1            3051   12311   Walk-up         2nd & Hill   7th & Broadway
# 2            3075   05992   Walk-up         Main & 1st   Broadway & 9th
#
#    duration        date  month  weekday  day  hour  \
# 0       7.0  2019-01-01      1        1    1     0
# 1       6.0  2019-01-01      1        1    1     0
# 2      32.0  2019-01-01      1        1    1     0
#
#                           route station_name_x            start_coords  \
# 0  2nd & Hill to 7th & Broadway     2nd & Hill  (34.05287, -118.24749)
# 1  2nd & Hill to 7th & Broadway     2nd & Hill  (34.05287, -118.24749)
# 2  Main & 1st to Broadway & 9th     Main & 1st  (34.05194, -118.24353)
#
#    station_name_y              end_coords
# 0             NaN                     NaN
# 1             NaN                     NaN
# 2  Broadway & 9th  (34.04211, -118.25619)

# %%
# cleaning dataframe
la_coords = df_2.drop('station_name_x', axis=1)
la_coords = la_coords.drop('station_name_y', axis=1)
la_coords.head(3)
# Out:
#    Unnamed: 0          start_time            end_time  start_station_id  \
# 0           0 2019-01-01 00:07:00 2019-01-01 00:14:00              3046
# 1           1 2019-01-01 00:08:00 2019-01-01 00:14:00              3046
# 2           2 2019-01-01 00:18:00 2019-01-01 00:50:00              3030
#
#    end_station_id bike_id user_type start_station_name end_station_name  \
# 0            3051   06468   Walk-up         2nd & Hill   7th & Broadway
# 1            3051   12311   Walk-up         2nd & Hill   7th & Broadway
# 2            3075   05992   Walk-up         Main & 1st   Broadway & 9th
#
#    duration        date  month  weekday  day  hour  \
# 0       7.0  2019-01-01      1        1    1     0
# 1       6.0  2019-01-01      1        1    1     0
# 2      32.0  2019-01-01      1        1    1     0
#
#                           route            start_coords  \
# 0  2nd & Hill to 7th & Broadway  (34.05287, -118.24749)
# 1  2nd & Hill to 7th & Broadway  (34.05287, -118.24749)
# 2  Main & 1st to Broadway & 9th  (34.05194, -118.24353)
#
#                end_coords
# 0                     NaN
# 1                     NaN
# 2  (34.04211, -118.25619)

# %%
# saving data set
la_coords.to_csv("la_incl_coordinates.csv")

# %%
# Out:
# 283135
