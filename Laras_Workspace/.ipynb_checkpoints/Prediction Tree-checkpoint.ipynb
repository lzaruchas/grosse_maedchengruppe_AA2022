# %%
# See workshop 7
import warnings
warnings.filterwarnings('ignore')

import random

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, export_graphviz
import graphviz

# %matplotlib inline

# %% [markdown]
# ## Data Preparation

# %%
df_la = pd.read_csv("datasets_merged_hour.csv", parse_dates=["date_time"], low_memory=False)
df_la["Day"] = df_la["date_time"].apply(lambda x: x.day)
df_la["Hour"] = df_la["date_time"].apply(lambda x: x.hour)
df_la.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8732 entries, 0 to 8731
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      8732 non-null   int64
#  1   date_time       8732 non-null   datetime64[ns]
#  2   max_temp        8732 non-null   float64
#  3   min_temp        8732 non-null   float64
#  4   precip          8732 non-null   float64
#  5   num_trips_hour  8732 non-null   int64
#  6   Day             8732 non-null   int64
#  7   Hour            8732 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(4)
# memory usage: 545.9 KB

# %%
df_la.head(2)
# Out:
#    Unnamed: 0           date_time  max_temp  min_temp  precip  num_trips_hour  \
# 0           0 2019-01-01 01:00:00      15.6      15.6     0.0             128
# 1           1 2019-01-01 02:00:00      15.0      15.0     0.0             256
#
#    Day  Hour
# 0    1     1
# 1    1     2

# %%
df_la['num_trips_hour'].max()
# Out:
# 5280

# %% [markdown]
# ## Overview "features"

# %%
# Überflüssig?!
Xp = df_la["max_temp"].values
Yp = df_la["num_trips_hour"].values
plt.figure(figsize = (8,6))
plt.scatter(Xp, Yp, marker="x")
plt.xlabel("High Temperature (°C)")
plt.ylabel("Amount of Trips")
plt.show()

# %%
# Überflüssig?!
Xp = df_la["Hour"]
Yp = df_la["num_trips_hour"].values
plt.figure(figsize = (8,6))
plt.scatter(Xp, Yp, marker="x")
plt.xlabel("Hour")
plt.ylabel("Amount of Trips")
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
Xp = df_la["max_temp"].values # choose features from KPI 
Yp = df_la["num_trips_hour"].values
# choose all features:
# Xp = df_la[["max_temp"]].values
# and change .reshape((-1-1)) everywhere to 
# scaler = StandardScaler()
# Xp_sc = scaler.fit_transform(Xp)

# %%
def plot_tree_regression_line(tree_depth):

    # Fit regression model (to full data)
    Tree_reg = DecisionTreeRegressor(max_depth=tree_depth, criterion="mse") 
    Tree_reg.fit(Xp.reshape((-1,1)), Yp)
    Y_pred = Tree_reg.predict(Xp.reshape((-1,1)))
    
    attributes = Tree_reg.tree_

    # plot
    plt.figure(figsize = (8,6))
    plt.scatter(Xp, Yp, marker="x")
    plt.plot(np.arange(-5,45,1), Tree_reg.predict(np.arange(-5,45,1).reshape((-1,1))), marker="x", color='C1')
    plt.xlabel("Max Temperature (°C)", fontsize=16)
    plt.ylabel("Number of Trips", fontsize=16)
    
    print("number of nodes: ", attributes.node_count)
    print("number of leafs: ", attributes.n_leaves)
    print("R^2: ", r2_score(Yp, Y_pred))
    
    
    #plt.savefig("Peak_Power_Regression_Lines_{}depth.pdf".format(tree_depth))

# %%
plot_tree_regression_line(8)
# Out:
# number of nodes:  101
# number of leafs:  51
# R^2:  0.0338206515265248

# %%
def plot_regression_tree_sklearn(tree_depth):

    # Fit regression model (to full data)
    model = DecisionTreeRegressor(max_depth=tree_depth)
    model.fit(Xp.reshape((-1,1)), Yp) 
    
    dot_data = export_graphviz(model,feature_names=["max_temp"]) # for all: add all features  
    
    graph = graphviz.Source(dot_data) 
    
    return graph

# %%
plot_regression_tree_sklearn(10)

# %% [markdown]
# ## Optimize predictive performance

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(Xp.reshape((-1,1)), Yp, random_state=0)

# fit decision tree (without limit on max_depth, i.e. tree will grow fully if alpha is set to 0)
tree_classifier = DecisionTreeClassifier(random_state=0, criterion="gini")

# compute cost_complexity_pruning_path
path = tree_classifier.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
path
# Out:
# {'ccp_alphas': array([0.00000000e+00, 9.16170408e-05, 1.03520983e-04, 1.11987264e-04,
#         1.19917158e-04, 1.20156476e-04, 1.24048150e-04, 1.24165584e-04,
#         1.25837313e-04, 1.27135266e-04, 1.27245890e-04, 1.32335726e-04,
#         1.35728949e-04, 1.36732108e-04, 1.38660636e-04, 1.40675809e-04,
#         1.41814585e-04, 1.42697177e-04, 1.46886016e-04, 1.48940359e-04,
#         1.50216626e-04, 1.52695068e-04, 1.54020434e-04, 1.55095243e-04,
#         1.56334676e-04, 1.60117745e-04, 1.62228175e-04, 1.69734952e-04,
#         1.77020254e-04, 1.80730553e-04, 1.81642504e-04, 1.82805856e-04,
#         1.88204085e-04, 1.94590342e-04, 1.97334000e-04, 1.98946531e-04,
#         2.05226219e-04, 2.15573147e-04, 2.30876193e-04, 2.48108634e-04,
#         2.65180986e-04, 3.41180858e-04, 5.64713667e-04, 7.50758361e-04]),
#  'impurities': array([0.97337152, 0.97346314, 0.97356666, 0.97367865, 0.97379856,
#         0.97403888, 0.97428697, 0.9745353 , 0.97466114, 0.97478828,
#         0.97491552, 0.97504786, 0.97531932, 0.97545605, 0.97559471,
#         0.97601674, 0.97615855, 0.97630125, 0.97644813, 0.97659708,
#         0.97674729, 0.97689999, 0.97705401, 0.9772091 , 0.97752177,
#         0.97784201, 0.97800424, 0.97817397, 0.97835099, 0.97889318,
#         0.97907482, 0.97925763, 0.97944583, 0.97964043, 0.97983776,
#         0.98003671, 0.98024193, 0.9804575 , 0.98068838, 0.9811846 ,
#         0.98144978, 0.98179096, 0.98235567, 0.98310643])}

# %%
#plot cost_complexity_pruning_path

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(ccp_alphas[:-1], impurities[:-1], marker='o', drawstyle="steps-post")  # we remove the last alpha as this corresponds to a tree with only the root node
ax.set_xlabel("effective alpha",fontsize=16)
ax.set_ylabel("total impurity of leaves",fontsize=16)
ax.set_title("Total Impurity vs effective alpha for training set",fontsize=16)

plt.savefig("Determining_Alpha.pdf")

# %% [markdown]
# ### Train a decision tree using the effective alphas

# %%
# @lea, weißt du noch warum ihr das damals leicht umgeschrieben habt?
trees = []
for alpha in ccp_alphas:
    tree = DecisionTreeClassifier(random_state=0, ccp_alpha=alpha)
    tree.fit(X_train, y_train)
    trees.append(tree)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      trees[1].tree_.node_count, ccp_alphas[1]))
# Out:
# Number of nodes in the last tree is: 107 with ccp_alpha: 9.161704076958308e-05

# %%
trees = trees[:-1]
ccp_alphas = ccp_alphas[:-1]

node_counts = [tree.tree_.node_count for tree in trees]
depth = [tree.tree_.max_depth for tree in trees]
fig, ax = plt.subplots(1,2,figsize=(14,6))
ax[0].plot(ccp_alphas, node_counts, marker='o', drawstyle="steps-post")
ax[0].set_xlabel("Alpha",fontsize=16)
ax[0].set_ylabel("Number of nodes",fontsize=16)
ax[0].set_title("Number of nodes vs alpha",fontsize=16)
ax[1].plot(ccp_alphas, depth, marker='o', drawstyle="steps-post")
ax[1].set_xlabel("Alpha",fontsize=16)
ax[1].set_ylabel("Depth of tree",fontsize=16)
ax[1].set_title("Depth vs alpha",fontsize=16)
fig.tight_layout()

#plt.savefig("Pruning_effect.pdf")

# %%
len(ccp_alphas)
# Out:
# 43

# %%
scores_train = []
scores_val = []

# run loop
for ccp_alpha in ccp_alphas:
    
    model = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    model.fit(X_train, y_train)    
    
    from sklearn.metrics import accuracy_score
    accuracy_train = accuracy_score(y_train, model.predict(X_train))
    accuracy_val = accuracy_score(y_test, model.predict(X_test))
    scores_val.append(accuracy_val)
    scores_train.append(accuracy_train)
    
# collect results in DF
df = pd.DataFrame(columns=["alpha","train_score","test_score"])
df["alpha"]=ccp_alphas
df["train_score"] = scores_train
df["test_score"] = scores_val

df.sort_values("test_score",ascending=False).head(5)
# Out:
#        alpha  train_score  test_score
# 41  0.000341     0.050695    0.046725
# 35  0.000199     0.059551    0.046267
# 21  0.000153     0.064590    0.045350
# 22  0.000154     0.064285    0.045350
# 19  0.000149     0.064743    0.045350

# %%
plt.subplots(figsize=(8,6))
plt.plot(df["alpha"],df["train_score"], marker='o')
plt.plot(df["alpha"],df["test_score"], marker='o')
plt.legend(["train","test"])
plt.xlabel("effective alpha",fontsize=16)
plt.ylabel("accuracy",fontsize=16)
plt.title("Accuracy for different alpha",fontsize=16)
#plt.savefig("alpha_tuning.pdf")
plt.show()
